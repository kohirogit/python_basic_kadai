# %%
class Human:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def printinfo(self):
        print(f"名前: {self.name}")
        print(f"年齢: {self.age}")


#代入
human1 = Human("A", 30)

#表示
human1.printinfo()
# Out:
# 名前: A
# 年齢: 30
